# %%
# Importing libraries required for data cleaning and performing eda
import pandas as pd
import numpy as np
import plotly.express as px

# %%
# Reading csv file
mp=pd.read_csv('/content/Mobile phone price.csv')

# %%
mp.sample(5)
# Out:
#        Brand              Model Storage  RAM  Screen Size (inches)  \
# 77     Apple          iPhone 13    128GB  4GB                  6.1
# 166   Realme                C21     64GB  3GB                  6.5
# 363  Samsung   Galaxy Note20 5G      256    8                  6.7
# 351  Samsung     Galaxy S21+ 5G      256    8                  6.7
# 362    Apple  iPhone 11 Pro Max       64    4                  6.5
#
#           Camera (MP)  Battery Capacity (mAh) Price ($)
# 77        12MP + 12MP                    2815     $799
# 166  13MP + 2MP + 2MP                    5000     $129
# 363          12+64+12                    4300       999
# 351          12+64+12                    4800       999
# 362          12+12+12                    3969      1099

# %%
mp.shape
# Out:
# (407, 8)

# %%
# To check null values and datatype
mp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 407 entries, 0 to 406
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Brand                   407 non-null    object
#  1   Model                   407 non-null    object
#  2   Storage                 407 non-null    object
#  3   RAM                     407 non-null    object
#  4   Screen Size (inches)    407 non-null    object
#  5   Camera (MP)             407 non-null    object
#  6   Battery Capacity (mAh)  407 non-null    int64
#  7   Price ($)               407 non-null    object
# dtypes: int64(1), object(7)
# memory usage: 25.6+ KB

# %%
# Checking duplicates
mp.duplicated().sum()
# Out:
# 26

# %%
# Dropping duplicates
mp.drop_duplicates(inplace=True)

# %%
# Checking duplicates again
mp.duplicated().sum()
# Out:
# 0

# %%
# Removing $ sign and comma from price column
mp['Price ($)'] = mp['Price ($)'].str.replace('$', '', regex=False)
mp['Price ($)'] = mp['Price ($)'].str.replace(',', '', regex=False)
mp['Price ($)']
# Out:
# 0       999
# 1      1199
# 2       899
# 3       279
# 4       799
#        ...
# 401     329
# 402    1049
# 403     349
# 404    1099
# 405     429
# Name: Price ($), Length: 381, dtype: object

# %%
# Converting datatype of price in float
mp['Price ($)']=mp['Price ($)'].astype(float)
mp.info()
mp['Price ($)']
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 381 entries, 0 to 405
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Brand                   381 non-null    object
#  1   Model                   381 non-null    object
#  2   Storage                 381 non-null    object
#  3   RAM                     381 non-null    object
#  4   Screen Size (inches)    381 non-null    object
#  5   Camera (MP)             381 non-null    object
#  6   Battery Capacity (mAh)  381 non-null    int64
#  7   Price ($)               381 non-null    float64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 26.8+ KB
# 0       999.0
# 1      1199.0
# 2       899.0
# 3       279.0
# 4       799.0
#         ...
# 401     329.0
# 402    1049.0
# 403     349.0
# 404    1099.0
# 405     429.0
# Name: Price ($), Length: 381, dtype: float64

# %%
# Converting price usd to inr
mp['Price ($)']=mp['Price ($)']*86.21
mp['Price ($)']
# Out:
# 0       86123.79
# 1      103365.79
# 2       77502.79
# 3       24052.59
# 4       68881.79
#          ...
# 401     28363.09
# 402     90434.29
# 403     30087.29
# 404     94744.79
# 405     36984.09
# Name: Price ($), Length: 381, dtype: float64

# %%
# Converting datatype of price in int
mp['Price ($)']=mp['Price ($)'].astype(int)
mp['Price ($)']
# Out:
# 0       86123
# 1      103365
# 2       77502
# 3       24052
# 4       68881
#         ...
# 401     28363
# 402     90434
# 403     30087
# 404     94744
# 405     36984
# Name: Price ($), Length: 381, dtype: int64

# %%
# Renaming price column name
mp.rename(columns={'Price ($)':'Price'},inplace=True)
mp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 381 entries, 0 to 405
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Brand                   381 non-null    object
#  1   Model                   381 non-null    object
#  2   Storage                 381 non-null    object
#  3   RAM                     381 non-null    object
#  4   Screen Size (inches)    381 non-null    object
#  5   Camera (MP)             381 non-null    object
#  6   Battery Capacity (mAh)  381 non-null    int64
#  7   Price                   381 non-null    int64
# dtypes: int64(2), object(6)
# memory usage: 26.8+ KB

# %%
mp.columns
# Out:
# Index(['Brand', 'Model', 'Storage ', 'RAM ', 'Screen Size (inches)',
#        'Camera (MP)', 'Battery Capacity (mAh)', 'Price'],
#       dtype='object')

# %%
# Removing GB and replacing TB with 3 zeroes extra in storage column
mp['Storage ']=mp['Storage '].str.replace('GB','')
mp['Storage ']=mp['Storage '].str.replace('TB','000')
mp['Storage ']
# Out:
# 0      128
# 1      256
# 2      128
# 3      128
# 4      128
#        ...
# 401     128
# 402     128
# 403     128
# 404     128
# 405     128
# Name: Storage , Length: 381, dtype: object

# %%
# Converting storage datatype
mp['Storage ']=mp['Storage '].astype(int)

# %%
# Renaming storage's column name
mp.rename(columns={'Storage ':'Storage(GB)'},inplace=True)
mp.columns
# Out:
# Index(['Brand', 'Model', 'Storage(GB)', 'RAM ', 'Screen Size (inches)',
#        'Camera (MP)', 'Battery Capacity (mAh)', 'Price'],
#       dtype='object')

# %%
# Removing GB in RAM column
mp['RAM ']=mp['RAM '].str.replace('GB','')
mp['RAM ']
# Out:
# 0       6
# 1      12
# 2       8
# 3       6
# 4       8
#       ...
# 401      4
# 402      8
# 403      6
# 404      6
# 405      8
# Name: RAM , Length: 381, dtype: object

# %%
# Converting RAM datatype
mp['RAM ']=mp['RAM '].astype(int)
mp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 381 entries, 0 to 405
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Brand                   381 non-null    object
#  1   Model                   381 non-null    object
#  2   Storage(GB)             381 non-null    int64
#  3   RAM                     381 non-null    int64
#  4   Screen Size (inches)    381 non-null    object
#  5   Camera (MP)             381 non-null    object
#  6   Battery Capacity (mAh)  381 non-null    int64
#  7   Price                   381 non-null    int64
# dtypes: int64(4), object(4)
# memory usage: 26.8+ KB

# %%
# Renaming RAM's column name
mp.rename(columns={'RAM ':'RAM(GB)'},inplace=True)
mp.columns
# Out:
# Index(['Brand', 'Model', 'Storage(GB)', 'RAM(GB)', 'Screen Size (inches)',
#        'Camera (MP)', 'Battery Capacity (mAh)', 'Price'],
#       dtype='object')

# %%
mp['Camera (MP)'].value_counts()
# Out:
# Camera (MP)
# 13MP + 2MP + 2MP          28
# 48MP + 8MP + 2MP + 2MP    15
# 64MP + 8MP + 2MP          11
# 48+8+2+2                  10
# 48MP + 8MP + 2MP           9
#                           ..
# 64 + 12 + 8 + 5            1
# 48MP + 8MP + 5MP + 2MP     1
# 13MP                       1
# 64 + 2                     1
# 48+13+8+2                  1
# Name: count, Length: 143, dtype: int64

# %%
# Segregating the camera resolution based on some categories
'''
0-8MP
9-12MP
13-15MP
16+MP
Other
'''
def groupingCameraResolution(resolution):
    try:
        resolution_num = int(resolution.split('MP')[0])  # Extract numeric resolution
        if resolution_num <= 8:
            return '0-8MP'
        elif 8 < resolution_num <= 12:
            return '9-12MP'
        elif 12 < resolution_num <= 16:
            return '13-15MP'
        else:
            return '16+MP'
    except ValueError:
        return 'Other'
mp['Camera_Group'] = mp['Camera (MP)'].apply(groupingCameraResolution)

# %%
mp['Camera_Group'].value_counts()
# Out:
# Camera_Group
# Other      174
# 16+MP      138
# 13-15MP     48
# 9-12MP      14
# 0-8MP        7
# Name: count, dtype: int64

# %%
mp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 381 entries, 0 to 405
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Brand                   381 non-null    object
#  1   Model                   381 non-null    object
#  2   Storage(GB)             381 non-null    int64
#  3   RAM(GB)                 381 non-null    int64
#  4   Screen Size (inches)    381 non-null    object
#  5   Camera (MP)             381 non-null    object
#  6   Battery Capacity (mAh)  381 non-null    int64
#  7   Price                   381 non-null    int64
#  8   Camera_Group            381 non-null    object
# dtypes: int64(4), object(5)
# memory usage: 29.8+ KB

# %%
mp.sample(10)
# Out:
#         Brand            Model  Storage(GB)  RAM(GB) Screen Size (inches)  \
# 96   Motorola         Moto G60          128        6                  6.8
# 120     Nokia              G20           64        4                  6.5
# 239    Realme             C21Y           64        4                  6.5
# 27       Oppo           A74 5G          128        6                  6.5
# 231      Oppo              A94          128        8                 6.43
# 266      Vivo             Y51A          128        8                 6.58
# 253   Samsung       Galaxy F41           64        6                  6.4
# 172    Realme  Narzo 30 Pro 5G          128        6                  6.5
# 189   Samsung       Galaxy M52          128        6                  6.7
# 68      Apple        iPhone XR           64        3                  6.1
#
#                  Camera (MP)  Battery Capacity (mAh)  Price Camera_Group
# 96         108MP + 8MP + 2MP                    6000  24052        16+MP
# 120               48MP + 5MP                    5050  17155        16+MP
# 239         13MP + 2MP + 2MP                    5000  11983      13-15MP
# 27                48 + 2 + 2                    5000  25776        Other
# 231   48MP + 8MP + 2MP + 2MP                    4310  34397        16+MP
# 266         48MP + 8MP + 2MP                    5000  24914        16+MP
# 253         64MP + 8MP + 5MP                    6000  21466        16+MP
# 172         48MP + 8MP + 2MP                    5000  24052        16+MP
# 189  64MP + 12MP + 5MP + 5MP                    5000  38708        16+MP
# 68                   12 + 12                    2942  43018        Other

# %%
mp['Screen Size (inches)'].value_counts()
# Out:
# Screen Size (inches)
# 6.5               100
# 6.67               26
# 6.4                26
# 6.7                24
# 6.55               21
# 6.43               20
# 6.51               17
# 6.1                16
# 6.53               15
# 6.58               14
# 6.6                14
# 6.52               13
# 6.8                 8
# 6.44                8
# 6.39                6
# 6.3                 4
# 6.82                4
# 6.81                4
# 6.2                 4
# 6.78                4
# 4.7                 4
# 6.62                3
# 6.9                 3
# 4.5                 2
# 5.4                 2
# 5.5                 2
# 6                   2
# 6.72                2
# 6.15                1
# 7.6 (unfolded)      1
# 6.49                1
# 6.47                1
# 5.7                 1
# 6.8 + 3.9           1
# 6.76                1
# 6.35                1
# 6.22                1
# 5.99                1
# 5.9                 1
# 6.56                1
# 6.57                1
# Name: count, dtype: int64

# %%
# Segregating the screen size based on below categories
'''
Below 5 inches
5-5.5 inches
5.5-6 inches
6-6.5 inches
6.5+ inches
'''
def groupScreenSize(size):
  try:
    size_num = float(size)
    if size_num < 5:
      return 'Below 5 inches'
    elif 5 <= size_num < 5.5:
      return '5-5.5 inches'
    elif 5.5 <= size_num < 6:
      return '5.5-6 inches'
    elif 6 <= size_num < 6.5:
      return '6-6.5 inches'
    else:
      return '6.5+ inches'
  except ValueError:
    return 'Other'
mp['Screen_Group'] = mp['Screen Size (inches)'].apply(groupScreenSize)

# %%
mp['Screen_Group'].value_counts()
# Out:
# Screen_Group
# 6.5+ inches       275
# 6-6.5 inches       91
# Below 5 inches      6
# 5.5-6 inches        5
# 5-5.5 inches        2
# Other               2
# Name: count, dtype: int64

# %%
mp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 381 entries, 0 to 405
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Brand                   381 non-null    object
#  1   Model                   381 non-null    object
#  2   Storage(GB)             381 non-null    int64
#  3   RAM(GB)                 381 non-null    int64
#  4   Screen Size (inches)    381 non-null    object
#  5   Camera (MP)             381 non-null    object
#  6   Battery Capacity (mAh)  381 non-null    int64
#  7   Price                   381 non-null    int64
#  8   Camera_Group            381 non-null    object
#  9   Screen_Group            381 non-null    object
# dtypes: int64(4), object(6)
# memory usage: 32.7+ KB

# %% [markdown]
# #EDA

# %% [markdown]
# # Top 10 Most Expensive Mobile Phone Models by Brand

# %%
# sorting price for getting top 10 models with high price
top_10_models=mp.sort_values(by=['Price'], ascending=False).head(10)

# %%
px.bar(top_10_models, x='Brand',y='Price', color='Model', color_discrete_sequence=px.colors.qualitative.Pastel1,
    title='Top 10 Mobile Phone Models with Highest Prices',
    labels={'Model': 'Mobile Phone Model', 'Price': 'Price'})
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="fa8e720f-d80f-4c2d-828a-62bd3282a7e2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fa8e720f-d80f-4c2d-828a-62bd3282a7e2")) {                    Plotly.newPlot(                        "fa8e720f-d80f-4c2d-828a-62bd3282a7e2",                        [{"alignmentgroup":"True","hovertemplate":"Mobile Phone Model=Galaxy Z Fold2 5G\u003cbr\u003eBrand=%{x}\u003cbr\u003ePrice=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Galaxy Z Fold2 5G","marker":{"color":"rgb(251,180,174)","pattern":{"shape":""}},"name":"Galaxy Z Fold2 5G","offsetgroup":"Galaxy Z Fold2 5G","orientation":"v","showlegend":true,"textposition":"auto","x":["Samsung"],"xaxis":"x","y":[172333],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Mobile Phone Model=P40 Pro+\u003cbr\u003eBrand=%{x}\u003cbr\u003ePrice=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"P40 Pro+","marker":{"color":"rgb(179,205,227)","pattern":{"shape":""}},"name":"P40 Pro+","offsetgroup":"P40 Pro+","orientation":"v","showlegend":true,"textposition":"auto","x":["Huawei"],"xaxis":"x","y":[120607],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Mobile Phone Model=Galaxy S20 Ultra 5G\u003cbr\u003eBrand=%{x}\u003cbr\u003ePrice=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Galaxy S20 Ultra 5G","marker":{"color":"rgb(204,235,197)","pattern":{"shape":""}},"name":"Galaxy S20 Ultra 5G","offsetgroup":"Galaxy S20 Ultra 5G","orientation":"v","showlegend":true,"textposition":"auto","x":["Samsung","Samsung"],"xaxis":"x","y":[120607,103365],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Mobile Phone Model=Xperia 5 III\u003cbr\u003eBrand=%{x}\u003cbr\u003ePrice=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Xperia 5 III","marker":{"color":"rgb(222,203,228)","pattern":{"shape":""}},"name":"Xperia 5 III","offsetgroup":"Xperia 5 III","orientation":"v","showlegend":true,"textposition":"auto","x":["Sony"],"xaxis":"x","y":[111986],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Mobile Phone Model=iPhone 13 Pro Max\u003cbr\u003eBrand=%{x}\u003cbr\u003ePrice=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"iPhone 13 Pro Max","marker":{"color":"rgb(254,217,166)","pattern":{"shape":""}},"name":"iPhone 13 Pro Max","offsetgroup":"iPhone 13 Pro Max","orientation":"v","showlegend":true,"textposition":"auto","x":["Apple"],"xaxis":"x","y":[111986],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Mobile Phone Model=Galaxy Note 20 Ultra\u003cbr\u003eBrand=%{x}\u003cbr\u003ePrice=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Galaxy Note 20 Ultra","marker":{"color":"rgb(255,255,204)","pattern":{"shape":""}},"name":"Galaxy Note 20 Ultra","offsetgroup":"Galaxy Note 20 Ultra","orientation":"v","showlegend":true,"textposition":"auto","x":["Samsung"],"xaxis":"x","y":[111986],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Mobile Phone Model=Galaxy S21 Ultra\u003cbr\u003eBrand=%{x}\u003cbr\u003ePrice=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Galaxy S21 Ultra","marker":{"color":"rgb(229,216,189)","pattern":{"shape":""}},"name":"Galaxy S21 Ultra","offsetgroup":"Galaxy S21 Ultra","orientation":"v","showlegend":true,"textposition":"auto","x":["Samsung"],"xaxis":"x","y":[103365],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Mobile Phone Model=Find X3 Pro\u003cbr\u003eBrand=%{x}\u003cbr\u003ePrice=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Find X3 Pro","marker":{"color":"rgb(253,218,236)","pattern":{"shape":""}},"name":"Find X3 Pro","offsetgroup":"Find X3 Pro","orientation":"v","sho ...

# %% [markdown]
# # Top 10 Least Expensive Mobile Phone Models by Brand

# %%
# sorting price for getting top 10 models with low price
top_10_models=mp.sort_values(by=['Price']).head(10)

# %%
px.bar(top_10_models, x='Brand',y='Price', color='Model', color_discrete_sequence=px.colors.qualitative.Pastel1,
    title='Top 10 Mobile Phone Models with lowest Prices',
    labels={'Model': 'Mobile Phone Model', 'Price': 'Price'})
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="9de36bb2-40d9-46fb-b1c7-3f057f1b5a41" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9de36bb2-40d9-46fb-b1c7-3f057f1b5a41")) {                    Plotly.newPlot(                        "9de36bb2-40d9-46fb-b1c7-3f057f1b5a41",                        [{"alignmentgroup":"True","hovertemplate":"Mobile Phone Model=Narzo 50i\u003cbr\u003eBrand=%{x}\u003cbr\u003ePrice=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Narzo 50i","marker":{"color":"rgb(251,180,174)","pattern":{"shape":""}},"name":"Narzo 50i","offsetgroup":"Narzo 50i","orientation":"v","showlegend":true,"textposition":"auto","x":["Realme"],"xaxis":"x","y":[8534],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Mobile Phone Model=C11 2021\u003cbr\u003eBrand=%{x}\u003cbr\u003ePrice=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"C11 2021","marker":{"color":"rgb(179,205,227)","pattern":{"shape":""}},"name":"C11 2021","offsetgroup":"C11 2021","orientation":"v","showlegend":true,"textposition":"auto","x":["Realme","Realme"],"xaxis":"x","y":[8534,8534],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Mobile Phone Model=Moto E7i Power\u003cbr\u003eBrand=%{x}\u003cbr\u003ePrice=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Moto E7i Power","marker":{"color":"rgb(204,235,197)","pattern":{"shape":""}},"name":"Moto E7i Power","offsetgroup":"Moto E7i Power","orientation":"v","showlegend":true,"textposition":"auto","x":["Motorola"],"xaxis":"x","y":[8534],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Mobile Phone Model=C20 Plus\u003cbr\u003eBrand=%{x}\u003cbr\u003ePrice=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"C20 Plus","marker":{"color":"rgb(222,203,228)","pattern":{"shape":""}},"name":"C20 Plus","offsetgroup":"C20 Plus","orientation":"v","showlegend":true,"textposition":"auto","x":["Nokia","Nokia"],"xaxis":"x","y":[8534,9396],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Mobile Phone Model=C11\u003cbr\u003eBrand=%{x}\u003cbr\u003ePrice=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"C11","marker":{"color":"rgb(254,217,166)","pattern":{"shape":""}},"name":"C11","offsetgroup":"C11","orientation":"v","showlegend":true,"textposition":"auto","x":["Realme"],"xaxis":"x","y":[8534],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Mobile Phone Model=C20\u003cbr\u003eBrand=%{x}\u003cbr\u003ePrice=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"C20","marker":{"color":"rgb(255,255,204)","pattern":{"shape":""}},"name":"C20","offsetgroup":"C20","orientation":"v","showlegend":true,"textposition":"auto","x":["Realme"],"xaxis":"x","y":[8534],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Mobile Phone Model=C21Y\u003cbr\u003eBrand=%{x}\u003cbr\u003ePrice=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"C21Y","marker":{"color":"rgb(229,216,189)","pattern":{"shape":""}},"name":"C21Y","offsetgroup":"C21Y","orientation":"v","showlegend":true,"textposition":"auto","x":["Realme"],"xaxis":"x","y":[10258],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Mobile Phone Model=1.4\u003cbr\u003eBrand=%{x}\u003cbr\u003ePrice=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"1.4","marker":{"color":"rgb(253,218,236)","pattern":{"shape":""}},"name":"1.4","offsetgroup":"1.4","orientation":"v","showlegend":true,"textposition":"auto","x":["Nokia"],"xaxis":"x","y":[10258],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111 ...

# %% [markdown]
# #Average Phone Price by RAM Size

# %%
ram_price=mp.groupby('RAM(GB)')['Price'].mean().reset_index()
ram_price
# Out:
#    RAM(GB)          Price
# 0        2    9866.545455
# 1        3   22382.727273
# 2        4   23738.545455
# 3        5   34397.000000
# 4        6   32890.777778
# 5        8   47338.288889
# 6       12   85261.000000
# 7       16  120607.000000

# %%
px.line(ram_price, x='RAM(GB)', y='Price', markers=True,
       labels={'RAM(GB)':'RAM','Price':'Price'},
       title='Average Phone Price by RAM Size')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="dff22895-cda1-4cca-bf18-682305d3dad2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("dff22895-cda1-4cca-bf18-682305d3dad2")) {                    Plotly.newPlot(                        "dff22895-cda1-4cca-bf18-682305d3dad2",                        [{"hovertemplate":"RAM=%{x}\u003cbr\u003ePrice=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"","orientation":"v","showlegend":false,"x":[2,3,4,5,6,8,12,16],"xaxis":"x","y":[9866.545454545454,22382.727272727272,23738.545454545456,34397.0,32890.77777777778,47338.28888888889,85261.0,120607.0],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"t ...

# %% [markdown]
# # Top 10 Brand wrt Average Price

# %%
# Calculating price by brand
brand_price=mp.groupby('Brand')['Price'].mean().reset_index()
brand_price=brand_price.sort_values(by='Price', ascending=False).head(10)
brand_price
# Out:
#          Brand          Price
# 13        Sony  111986.000000
# 1         Asus   75346.750000
# 5       Huawei   67516.166667
# 0        Apple   65494.214286
# 4       Google   60260.000000
# 9      OnePlus   57674.000000
# 6           LG   53076.000000
# 2   Blackberry   43018.000000
# 12     Samsung   41944.780822
# 10        Oppo   32884.471698

# %%
px.bar(brand_price, x='Brand', y='Price', color='Brand', color_discrete_sequence=px.colors.qualitative.Pastel1,
       title='Top 10 brand wrt average price')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="64fb953d-30f8-4931-b4b1-1dac25ae6dc4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("64fb953d-30f8-4931-b4b1-1dac25ae6dc4")) {                    Plotly.newPlot(                        "64fb953d-30f8-4931-b4b1-1dac25ae6dc4",                        [{"alignmentgroup":"True","hovertemplate":"Brand=%{x}\u003cbr\u003ePrice=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Sony","marker":{"color":"rgb(251,180,174)","pattern":{"shape":""}},"name":"Sony","offsetgroup":"Sony","orientation":"v","showlegend":true,"textposition":"auto","x":["Sony"],"xaxis":"x","y":[111986.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Brand=%{x}\u003cbr\u003ePrice=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Asus","marker":{"color":"rgb(179,205,227)","pattern":{"shape":""}},"name":"Asus","offsetgroup":"Asus","orientation":"v","showlegend":true,"textposition":"auto","x":["Asus"],"xaxis":"x","y":[75346.75],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Brand=%{x}\u003cbr\u003ePrice=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Huawei","marker":{"color":"rgb(204,235,197)","pattern":{"shape":""}},"name":"Huawei","offsetgroup":"Huawei","orientation":"v","showlegend":true,"textposition":"auto","x":["Huawei"],"xaxis":"x","y":[67516.16666666667],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Brand=%{x}\u003cbr\u003ePrice=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Apple","marker":{"color":"rgb(222,203,228)","pattern":{"shape":""}},"name":"Apple","offsetgroup":"Apple","orientation":"v","showlegend":true,"textposition":"auto","x":["Apple"],"xaxis":"x","y":[65494.21428571428],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Brand=%{x}\u003cbr\u003ePrice=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Google","marker":{"color":"rgb(254,217,166)","pattern":{"shape":""}},"name":"Google","offsetgroup":"Google","orientation":"v","showlegend":true,"textposition":"auto","x":["Google"],"xaxis":"x","y":[60260.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Brand=%{x}\u003cbr\u003ePrice=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"OnePlus","marker":{"color":"rgb(255,255,204)","pattern":{"shape":""}},"name":"OnePlus","offsetgroup":"OnePlus","orientation":"v","showlegend":true,"textposition":"auto","x":["OnePlus"],"xaxis":"x","y":[57674.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Brand=%{x}\u003cbr\u003ePrice=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"LG","marker":{"color":"rgb(229,216,189)","pattern":{"shape":""}},"name":"LG","offsetgroup":"LG","orientation":"v","showlegend":true,"textposition":"auto","x":["LG"],"xaxis":"x","y":[53076.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Brand=%{x}\u003cbr\u003ePrice=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Blackberry","marker":{"color":"rgb(253,218,236)","pattern":{"shape":""}},"name":"Blackberry","offsetgroup":"Blackberry","orientation":"v","showlegend":true,"textposition":"auto","x":["Blackberry"],"xaxis":"x","y":[43018.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Brand=%{x}\u003cbr\u003ePrice=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Samsung","marker":{"color":"rgb(242,242,242)","pattern":{"shape":""}},"name":"Samsung","offsetgroup":"Samsung","orientation":"v","showlegend":true,"textposition":"auto","x":["Samsung"],"xaxis":"x","y":[41944.78082191781],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Brand=%{x}\u003cbr\u003ePrice=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","leg ...

# %% [markdown]
# # Average battery capacity by brand

# %%
battery_by_brand = mp.groupby('Brand')['Battery Capacity (mAh)'].mean().reset_index()

# %%
px.bar(battery_by_brand, x='Brand', y='Battery Capacity (mAh)', color='Brand', color_discrete_sequence=px.colors.qualitative.Pastel1,
       title='Average Battery Capacity by Brand')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="c0aa008b-0cae-4d6f-b590-65e1c34069dd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c0aa008b-0cae-4d6f-b590-65e1c34069dd")) {                    Plotly.newPlot(                        "c0aa008b-0cae-4d6f-b590-65e1c34069dd",                        [{"alignmentgroup":"True","hovertemplate":"Brand=%{x}\u003cbr\u003eBattery Capacity (mAh)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Apple","marker":{"color":"rgb(251,180,174)","pattern":{"shape":""}},"name":"Apple","offsetgroup":"Apple","orientation":"v","showlegend":true,"textposition":"auto","x":["Apple"],"xaxis":"x","y":[2923.8928571428573],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Brand=%{x}\u003cbr\u003eBattery Capacity (mAh)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Asus","marker":{"color":"rgb(179,205,227)","pattern":{"shape":""}},"name":"Asus","offsetgroup":"Asus","orientation":"v","showlegend":true,"textposition":"auto","x":["Asus"],"xaxis":"x","y":[5000.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Brand=%{x}\u003cbr\u003eBattery Capacity (mAh)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Blackberry","marker":{"color":"rgb(204,235,197)","pattern":{"shape":""}},"name":"Blackberry","offsetgroup":"Blackberry","orientation":"v","showlegend":true,"textposition":"auto","x":["Blackberry"],"xaxis":"x","y":[3500.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Brand=%{x}\u003cbr\u003eBattery Capacity (mAh)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"CAT","marker":{"color":"rgb(222,203,228)","pattern":{"shape":""}},"name":"CAT","offsetgroup":"CAT","orientation":"v","showlegend":true,"textposition":"auto","x":["CAT"],"xaxis":"x","y":[4200.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Brand=%{x}\u003cbr\u003eBattery Capacity (mAh)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Google","marker":{"color":"rgb(254,217,166)","pattern":{"shape":""}},"name":"Google","offsetgroup":"Google","orientation":"v","showlegend":true,"textposition":"auto","x":["Google"],"xaxis":"x","y":[3995.8],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Brand=%{x}\u003cbr\u003eBattery Capacity (mAh)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Huawei","marker":{"color":"rgb(255,255,204)","pattern":{"shape":""}},"name":"Huawei","offsetgroup":"Huawei","orientation":"v","showlegend":true,"textposition":"auto","x":["Huawei"],"xaxis":"x","y":[4161.666666666667],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Brand=%{x}\u003cbr\u003eBattery Capacity (mAh)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"LG","marker":{"color":"rgb(229,216,189)","pattern":{"shape":""}},"name":"LG","offsetgroup":"LG","orientation":"v","showlegend":true,"textposition":"auto","x":["LG"],"xaxis":"x","y":[4100.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Brand=%{x}\u003cbr\u003eBattery Capacity (mAh)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Motorola","marker":{"color":"rgb(253,218,236)","pattern":{"shape":""}},"name":"Motorola","offsetgroup":"Motorola","orientation":"v","showlegend":true,"textposition":"auto","x":["Motorola"],"xaxis":"x","y":[5022.727272727273],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Brand=%{x}\u003cbr\u003eBattery Capacity (mAh)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Nokia","marker":{"color":"rgb(242,242,242)","pattern":{"shape":""}},"name":"Nokia","offsetgroup":"Nokia","orientation":"v","showlegend":true,"textposition":"auto","x":["Nokia"],"xaxis":"x","y":[4500.0],"yaxis":"y ...

# %% [markdown]
# # Price vs. Screen Size by Brand

# %%
px.scatter(mp, x='Screen_Group', y='Price', color='Brand',
           title='Price vs. Screen Size by Brand',
           labels={'Screen Size (inches)': 'Screen Size', 'Price': 'Price'})
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="77c3dfd9-c605-4118-b887-8b1d5e842d9d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("77c3dfd9-c605-4118-b887-8b1d5e842d9d")) {                    Plotly.newPlot(                        "77c3dfd9-c605-4118-b887-8b1d5e842d9d",                        [{"hovertemplate":"Brand=Apple\u003cbr\u003eScreen_Group=%{x}\u003cbr\u003ePrice=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Apple","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Apple","orientation":"v","showlegend":true,"x":["6-6.5 inches","6-6.5 inches","5-5.5 inches","6-6.5 inches","Below 5 inches","6-6.5 inches","6.5+ inches","6.5+ inches","Below 5 inches","6-6.5 inches","6-6.5 inches","6-6.5 inches","Below 5 inches","6.5+ inches","6-6.5 inches","6-6.5 inches","6-6.5 inches","6-6.5 inches","6.5+ inches","5.5-6 inches","6-6.5 inches","6.5+ inches","5-5.5 inches","Below 5 inches","6-6.5 inches","6-6.5 inches","6-6.5 inches","6.5+ inches"],"xaxis":"x","y":[86123,68881,60260,51639,34397,43018,94744,111986,34397,43018,51639,68881,34397,94744,68881,51639,68881,60260,94744,60260,43018,94744,77502,38708,86123,64571,51639,94744],"yaxis":"y","type":"scatter"},{"hovertemplate":"Brand=Samsung\u003cbr\u003eScreen_Group=%{x}\u003cbr\u003ePrice=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Samsung","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"Samsung","orientation":"v","showlegend":true,"x":["6.5+ inches","6.5+ inches","6.5+ inches","6-6.5 inches","6.5+ inches","6.5+ inches","6.5+ inches","6-6.5 inches","6-6.5 inches","6.5+ inches","6.5+ inches","6.5+ inches","6.5+ inches","6.5+ inches","6-6.5 inches","6.5+ inches","6.5+ inches","6.5+ inches","6.5+ inches","6-6.5 inches","6-6.5 inches","6-6.5 inches","6.5+ inches","6.5+ inches","6.5+ inches","6.5+ inches","6-6.5 inches","6.5+ inches","6.5+ inches","6.5+ inches","6-6.5 inches","6.5+ inches","6-6.5 inches","6-6.5 inches","6.5+ inches","6.5+ inches","6.5+ inches","6-6.5 inches","6-6.5 inches","6.5+ inches","6.5+ inches","6.5+ inches","6.5+ inches","6.5+ inches","6.5+ inches","6.5+ inches","6.5+ inches","6-6.5 inches","6.5+ inches","6.5+ inches","6-6.5 inches","6-6.5 inches","6-6.5 inches","6.5+ inches","6.5+ inches","6.5+ inches","6.5+ inches","6.5+ inches","6.5+ inches","6.5+ inches","6.5+ inches","6.5+ inches","6.5+ inches","6.5+ inches","6.5+ inches","6.5+ inches","6.5+ inches","6.5+ inches","Other","6.5+ inches","6-6.5 inches","6.5+ inches","6.5+ inches"],"xaxis":"x","y":[103365,86123,38708,68881,24052,11983,38708,19742,16293,13707,39570,36984,38708,20604,68881,38708,86123,60260,15431,24052,19742,24052,38708,18879,12845,103365,18879,26638,17155,38708,25776,40432,23190,20604,38708,16293,28363,18879,23190,36984,15431,12845,24052,32673,38708,15431,24052,21466,30087,11983,11207,11121,24052,111986,51639,38708,103365,15431,55950,34397,38708,24052,60260,86123,38708,86123,120607,17155,172333,28363,68881,103365,90434],"yaxis":"y","type":"scatter"},{"hovertemplate":"Brand=OnePlus\u003cbr\u003eScreen_Group=%{x}\u003cbr\u003ePrice=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"OnePlus","marker":{"color":"#00cc96","symbol":"circle"},"mode":"markers","name":"OnePlus","orientation":"v","showlegend":true,"x":["6.5+ inches","6-6.5 inches","6.5+ inches","6-6.5 inches","6-6.5 inches","6.5+ inches","6-6.5 inches","6.5+ inches","6.5+ inches","6.5+ inches","6.5+ inches","6-6.5 inches","6.5+ inches","6.5+ inches"],"xaxis":"x","y":[77502,28363,62847,34397,34397,83537,25776,64571,83537,86123,60260,38708,62847,64571],"yaxis":"y","type":"scatter"},{"hovertemplate":"Brand=Xiaomi\u003cbr\u003eScreen_Group=%{x}\u003cbr\u003ePrice=%{y}\u003cextra\u003e\u003c\u002fextr ...

# %% [markdown]
# # Distribution of Camera Group

# %%
camera_group=mp['Camera_Group'].value_counts().reset_index()
camera_group
# Out:
#   Camera_Group  count
# 0        Other    174
# 1        16+MP    138
# 2      13-15MP     48
# 3       9-12MP     14
# 4        0-8MP      7

# %%
px.pie(camera_group, values='count', names='Camera_Group', color_discrete_sequence=px.colors.qualitative.Pastel1,
       title='Distribution of Camera Resolution')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="5ea65215-9e52-455a-a197-3a7b2da5c4f7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5ea65215-9e52-455a-a197-3a7b2da5c4f7")) {                    Plotly.newPlot(                        "5ea65215-9e52-455a-a197-3a7b2da5c4f7",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Camera_Group=%{label}\u003cbr\u003ecount=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["Other","16+MP","13-15MP","9-12MP","0-8MP"],"legendgroup":"","name":"","showlegend":true,"values":[174,138,48,14,7],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0," ...

# %% [markdown]
# # Conclusion:
# The analysis of mobile phone prices and features shows important trends. Apple and Samsung are the top brands, and their phones are usually more expensive. The price of a phone is mainly influenced by its RAM and screen size with bigger RAM and larger screens making the phone cost more. Battery capacity is similar across most brands and camera resolution is usually in the middle range. Some brands even offer affordable phones without cutting back on important features.
